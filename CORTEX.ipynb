# %%
import os
import tempfile
import matplotlib.pyplot as plt
import cortex
import numpy as np

T_map = np.load("output/230611 ispc_tmap.npy")
vol_data = cortex.Volume(T_map.transpose(2,1,0),
                         "MNI", "fmriprep_3mm", cmap='RdBu_r',
                         vmin=-2, vmax=3)
cortex.webshow(vol_data)
# Out:
# Started server on port 14875
# <JS: window.viewer>

# %%
# import os
# import tempfile
# import matplotlib.pyplot as plt
# import cortex
# import numpy as np

# T_map = np.load("output/230608 IS-RSA_p1.npy")
# vol_data = cortex.Volume(T_map.transpose(2,1,0),
#                          "MNI", "fmriprep_3mm", cmap='RdBu_r',
#                          vmin=-20, vmax=20)
# cortex.webshow(vol_data)

# base_name = os.path.join(tempfile.mkdtemp(), 'fig')

# cmap = 'RdBu_r'
# #cmap_label = 'Edge selection'
# vol_data = cortex.Volume(T_map.transpose(2,1,0), "MNI", "fmriprep_3mm", cmap='RdBu_r',
#                          vmin=-0.2, vmax=0.2, colorbar=True)

# filenames = cortex.export.save_3d_views(
#                 vol_data, base_name=base_name,
#                 list_angles=['medial_pivot', 'lateral_pivot'], #medial_pivot or lateral_pivot
#                 list_surfaces=['inflated', 'inflated'],
#                 size=(1024 * 4, 768 * 2), trim=True,)
# print(filenames)
# fig = plt.figure(constrained_layout=True, dpi=200, figsize=(6,4))
# gs = fig.add_gridspec(2, 1, height_ratios=[4.95, 5.05])

# ax1 = fig.add_subplot(gs[0])
# ax1.imshow(plt.imread(filenames[0]), interpolation='gaussian')
# ax1.axis('off')

# ax2 = fig.add_subplot(gs[1])
# ax2.imshow(plt.imread(filenames[1]), interpolation='gaussian')
# ax2.axis('off')
# plt.subplots_adjust(hspace=0.01)
# Out:
# Started server on port 10598
# Started server on port 15958
# Stopping server
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#
# File ~/anaconda3/envs/cortex/lib/python3.11/site-packages/cortex/export/save_views.py:80, in save_3d_views(volume, base_name, list_angles, list_surfaces, viewer_params, interpolation, layers, size, trim, sleep)
#      78 handle = cortex.webshow(volume, **viewer_params)
#      79 # Wait for the viewer to be loaded
# ---> 80 time.sleep(sleep)
#      82 # Add interpolation and layers params only if we have a volume
#      83 if isinstance(volume, (cortex.Volume, cortex.Volume2D, cortex.VolumeRGB)):
#
# KeyboardInterrupt:
# Stopping server
# Stopping server
